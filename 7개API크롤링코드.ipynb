# %%
import urllib.request
from urllib.request import urlopen
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
인증키번호 : 1ae6afffca9a548f14e26b9a6ff251e0

# %%
# url만 각각 변경해서 해당하는 아래 코드로 넣어주시면 됩니다.
url = 'http://finlife.fss.or.kr/finlifeapi/companySearch.xml?auth=1ae6afffca9a548f14e26b9a6ff251e0&topFinGrpNo=020000&pageNo=1'

# %%
# url 받는부분
resultXML = urlopen(url)
result = resultXML.read()
xmlsoup=BeautifulSoup(result,'html.parser')
a = xmlsoup.find_all('product')
len(a)
# Out:
# 18

# %%
# 개인신용대출 API
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','fin_prdt_cd',
     'fin_prdt_nm','join_way','crdt_prdt_type','crdt_prdt_type_nm','cb_name',
     'dcls_strt_day','dcls_end_day','fin_co_subm_day','option_num'] #상품컬럼
e = ['금리구분 코드','금리구분',
     '은행(1~2)/비은행(1~3) 등급', '은행(3~4)/비은행(4) 등급',
     '은행(5~6)/비은행(5) 등급', '은행(7~8)/비은행(6) 등급',
     '은행(9~10)/비은행(7~10) 등급', '평균금리'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('fin_prdt_cd').text)  #금융상품코드
    b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
    b.append(a[i].find('join_way').text)  #가입방법
    b.append(a[i].find('crdt_prdt_type').text)  #대출종류코드
    b.append(a[i].find('crdt_prdt_type_nm').text)  #대출종류명
    b.append(a[i].find('cb_name').text)  #CB회사명
    b.append(a[i].find('dcls_strt_day').text)  #공시 시작일
    b.append(a[i].find('dcls_end_day').text)  #공시 종료일
    b.append(a[i].find('fin_co_subm_day').text)  #금융회사 제출일
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1]) 
        b.append(d[j].text.split('\n')[2]) 
        b.append(d[j].text.split('\n')[3])  
        b.append(d[j].text.split('\n')[4])  
        b.append(d[j].text.split('\n')[5])  
        b.append(d[j].text.split('\n')[6])  
        b.append(d[j].text.split('\n')[7])  
        b.append(d[j].text.split('\n')[8])
    c.append(b)
    b = []
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-698-257f5886b1cd> in <module>
#       8     b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
#       9     b.append(a[i].find('join_way').text)  #가입방법
# ---> 10     b.append(a[i].find('crdt_prdt_type').text)  #대출종류코드
#      11     b.append(a[i].find('crdt_prdt_type_nm').text)  #대출종류명
#      12     b.append(a[i].find('cb_name').text)  #CB회사명
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df

# %%
# 전세자금대출 API
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','fin_prdt_cd',
     'fin_prdt_nm','join_way','loan_inci_expn','erly_rpay_fee','dly_rate',
     'loan_lmt','dcls_strt_day','dcls_end_day','fin_co_subm_day','option_num'] #상품컬럼
e = ['대출상환유형 코드', '대출상환유형','대출 금리유형 코드',
    '대출금리유형','대출금리 최저','대출금리 최고','전월 취급 평균금리'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('fin_prdt_cd').text)  #금융상품코드
    b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
    b.append(a[i].find('join_way').text)  #가입방법
    b.append(a[i].find('loan_inci_expn').text)  #대출 부대비용
    b.append(a[i].find('erly_rpay_fee').text)  #중도상환수수료
    b.append(a[i].find('dly_rate').text)  #연체이자율
    b.append(a[i].find('loan_lmt').text)  #대출한도
    b.append(a[i].find('dcls_strt_day').text)  #공시 시작일
    b.append(a[i].find('dcls_end_day').text)  #공시 종료일
    b.append(a[i].find('fin_co_subm_day').text)  #금융회사 제출일
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1]) 
        b.append(d[j].text.split('\n')[2]) 
        b.append(d[j].text.split('\n')[3])  
        b.append(d[j].text.split('\n')[4])  
        b.append(d[j].text.split('\n')[5])  
        b.append(d[j].text.split('\n')[6])  
        b.append(d[j].text.split('\n')[7])  
    c.append(b)
    b = []

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df

# %%
df.to_excel('전세자금대출API.xlsx')

# %%
# 주택답모대출 API
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','fin_prdt_cd',
     'fin_prdt_nm','join_way','loan_inci_expn','erly_rpay_fee','dly_rate',
     'loan_lmt','dcls_strt_day','dcls_end_day','fin_co_subm_day','option_num'] #상품컬럼
e = ['담보유형 코드','담보유형',
     '대출상환유형 코드', '대출상환유형','대출 금리유형 코드',
    '대출금리유형','대출금리 최저','대출금리 최고','전월 취급 평균금리'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('fin_prdt_cd').text)  #금융상품코드
    b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
    b.append(a[i].find('join_way').text)  #가입방법
    b.append(a[i].find('loan_inci_expn').text)  #대출 부대비용
    b.append(a[i].find('erly_rpay_fee').text)  #중도상환수수료
    b.append(a[i].find('dly_rate').text)  #연체이자율
    b.append(a[i].find('loan_lmt').text)  #대출한도
    b.append(a[i].find('dcls_strt_day').text)  #공시 시작일
    b.append(a[i].find('dcls_end_day').text)  #공시 종료일
    b.append(a[i].find('fin_co_subm_day').text)  #금융회사 제출일
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1]) 
        b.append(d[j].text.split('\n')[2]) 
        b.append(d[j].text.split('\n')[3])  
        b.append(d[j].text.split('\n')[4])  
        b.append(d[j].text.split('\n')[5])  
        b.append(d[j].text.split('\n')[6])  
        b.append(d[j].text.split('\n')[7])  
        b.append(d[j].text.split('\n')[8])
        b.append(d[j].text.split('\n')[9])
    c.append(b)
    b = []

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df

# %%
df.to_excel('주택담보대출API2.xlsx')

# %%
# 연금저축 API
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','fin_prdt_cd',
     'fin_prdt_nm','join_way','pnsn_kind','pnsn_kind_nm','sale_strt_day',
     'mntn_cnt','prdt_type','prdt_type_nm','avg_prft_rate','dcls_rate',
     'guar_rate','btrm_prft_rate_1','btrm_prft_rate_2','btrm_prft_rate_3',
     'etc','sale_co','dcls_strt_day','dcls_end_day','fin_co_subm_day',
     'option_num'] #상품컬럼
e = ['연금 수령기간 코드','연금 수령기간',
     '연금 가입연령 코드','연금 가입 연령', '월 납입액 코드',
     '월 납입액','납입기간 코드','납입 기간','연금 개시연령 코드',
     '연금 개시연령','연금 수령액'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('fin_prdt_cd').text)  #금융상품코드
    b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
    b.append(a[i].find('join_way').text)  #가입방법
    b.append(a[i].find('pnsn_kind').text) #연금종류
    b.append(a[i].find('pnsn_kind_nm').text) #연금종류명
    b.append(a[i].find('sale_strt_day').text)  #판매게시일
    b.append(a[i].find('mntn_cnt').text)  #유지건수[단위: 건] 또는 설정액 [단위: 원]
    b.append(a[i].find('prdt_type').text)  #상품유형
    b.append(a[i].find('prdt_type_nm').text)  #상품유형명
    b.append(a[i].find('avg_prft_rate').text)   #연평균수익률
    b.append(a[i].find('dcls_rate').text)   #공시이율
    b.append(a[i].find('guar_rate').text)  #최저보증이율
    b.append(a[i].find('btrm_prft_rate_1').text)  #과거 수익률1
    b.append(a[i].find('btrm_prft_rate_2').text)  #과거 수익률2
    b.append(a[i].find('btrm_prft_rate_3').text)  #과거 수익률3
    b.append(a[i].find('etc').text)  #기타사항
    b.append(a[i].find('sale_co').text)  #판매사
    b.append(a[i].find('dcls_strt_day').text)  #공시 시작일
    b.append(a[i].find('dcls_end_day').text) # 공시 종료일
    b.append(a[i].find('fin_co_subm_day').text)  #금융회사 제출일
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1])  # 저축금리유형
        b.append(d[j].text.split('\n')[2])  # 저축금리유형명
        b.append(d[j].text.split('\n')[3])  # 적립유형
        b.append(d[j].text.split('\n')[4])  # 적립유형명
        b.append(d[j].text.split('\n')[5])  # 저축 기간
        b.append(d[j].text.split('\n')[6])  # 저축 금리
        b.append(d[j].text.split('\n')[7])  # 최고 우대금리
        b.append(d[j].text.split('\n')[8])
        b.append(d[j].text.split('\n')[9])
        b.append(d[j].text.split('\n')[10])
        b.append(d[j].text.split('\n')[11])
    c.append(b)
    b = []

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df

# %%
# 적금 API
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','fin_prdt_cd',
     'fin_prdt_nm','join_way','mtrt_int','spcl_cnd','join_deny',
     'join_member','etc_note','max_limit','dcls_strt_day','dcls_end_day',
     'fin_co_subm_day','option_num'] #상품컬럼
e = ['저축 금리 유형','저축 금리 유형명',
     '적립 유형', '적립 유형명','저축 기간',
    '저축 금리','최고 우대금리'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('fin_prdt_cd').text)  #금융상품코드
    b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
    b.append(a[i].find('join_way').text)  #가입방법
    b.append(a[i].find('mtrt_int').text)  #만기 후 이자율
    b.append(a[i].find('spcl_cnd').text)  #우대조건
    b.append(a[i].find('join_deny').text)  #가입제한
    b.append(a[i].find('join_member').text)  #가입대상
    b.append(a[i].find('etc_note').text)   #기타 유의사항
    b.append(a[i].find('max_limit').text)   #최고한도
    b.append(a[i].find('dcls_strt_day').text)  #공시 시작일
    b.append(a[i].find('dcls_end_day').text)  #공시 종료일
    b.append(a[i].find('fin_co_subm_day').text)  #금융회사 제출일
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1])  # 저축금리유형
        b.append(d[j].text.split('\n')[2])  # 저축금리유형명
        b.append(d[j].text.split('\n')[3])  # 적립유형
        b.append(d[j].text.split('\n')[4])  # 적립유형명
        b.append(d[j].text.split('\n')[5])  # 저축 기간
        b.append(d[j].text.split('\n')[6])  # 저축 금리
        b.append(d[j].text.split('\n')[7])  # 최고 우대금리
    c.append(b)
    b = []

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df

# %%
pd.DataFrame(c).to_excel('적금API.xlsx')

# %%
# 정기예금 API
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','fin_prdt_cd',
     'fin_prdt_nm','join_way','mtrt_int','spcl_cnd','join_deny',
     'join_member','etc_note','max_limit','dcls_strt_day','dcls_end_day',
     'fin_co_subm_day','option_num'] #상품컬럼
e = ['저축 금리 유형','저축 금리 유형명','저축 기간',
    '저축 금리','최고 우대금리'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('fin_prdt_cd').text)  #금융상품코드
    b.append(a[i].find('fin_prdt_nm').text)  #금융상품명
    b.append(a[i].find('join_way').text)  #가입방법
    b.append(a[i].find('mtrt_int').text)  #만기 후 이자율
    b.append(a[i].find('spcl_cnd').text)  #우대조건
    b.append(a[i].find('join_deny').text)  #가입제한
    b.append(a[i].find('join_member').text)
    b.append(a[i].find('etc_note').text)
    b.append(a[i].find('max_limit').text)
    b.append(a[i].find('dcls_strt_day').text)
    b.append(a[i].find('dcls_end_day').text)
    b.append(a[i].find('fin_co_subm_day').text)
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1])  # 저축금리유형
        b.append(d[j].text.split('\n')[2])  # 저축금리유형명
        b.append(d[j].text.split('\n')[3])  # 저축 기간
        b.append(d[j].text.split('\n')[4])  # 저축 금리
        b.append(d[j].text.split('\n')[5])  # 최고 우대금리
    c.append(b)
    b = []

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df
# Out:
#         0        1        2        3                   4   \
# 0   202007  0010345  애큐온저축은행  HK00002                정기적금
# 1   202007  0010345  애큐온저축은행  HK00003             직장인우대적금
# 2   202007  0010346  OSB저축은행    31000                정기적금
# 3   202007  0010349   디비저축은행     3100                정기적금
# 4   202007  0010349   디비저축은행     3138  DreamBig정기적금(10만원)
# ..     ...      ...      ...      ...                 ...
# 95  202007  0010467   융창저축은행   311000               e정기적금
# 96  202007  0010468   세람저축은행   310001                정기적금
# 97  202007  0010468   세람저축은행   310035            비대면 정기적금
# 98  202007  0010468   세람저축은행   310504        엄마의미소(美少) 적금
# 99  202007  0010468   세람저축은행   310601           내가디자인하는적금
#
#                        5                                                  6   \
# 0   영업점,인터넷,스마트폰,전화(텔레뱅킹)  - 만기 후 1개월 이내 해지 시 : 약정금리(2019.07.01 신규부터 적용)\...
# 1            영업점,인터넷,스마트폰  - 만기 후 1개월 이내 해지 시 : 약정금리(2019.07.01 신규부터 적용)\...
# ...

# %%
df.to_excel('????.xlsx')

# %%
# 금융회사 API코드
c = []
b = []
f = ['dcls_month','fin_co_no','kor_co_nm','dcls_chrg_man','homp_url','cal_tel','option_num'] #상품컬럼
e = ['지역구분','지역이름','점포소재여부'] # 옵션컬럼
g = []
for i in range(len(a)):
    b.append(a[i].find('dcls_month').text)  # 공시제출월
    b.append(a[i].find('fin_co_no').text)   #금융회사코드
    b.append(a[i].find('kor_co_nm').text)   #금융회사명
    b.append(a[i].find('dcls_chrg_man').text)  #공시담당자
    b.append(a[i].find('homp_url').text)  #홈페이지주소
    b.append(a[i].find('cal_tel').text)  #콜센터전화번호
    d = a[i].find_all('option')
    b.append(len(d))
    g.append(len(d))
    for j in range(len(d)):
        b.append(d[j].text.split('\n')[1])  # 지역구분
        b.append(d[j].text.split('\n')[2])  #지역이름
        b.append(d[j].text.split('\n')[3])  #점포소재여부
    c.append(b)
    b = []

# %%
# 데이터프레임 생성코드
h = e*max(g)
for i in h:
    f.append(i)
df = pd.DataFrame(c,columns = f)
df

# %%
df.to_excel('????.xlsx')
